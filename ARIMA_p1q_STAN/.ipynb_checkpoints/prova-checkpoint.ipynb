# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az

# %%
import fit_arima
import open_data

# %%
df = open_data.open()

# %%
stazione = 'S. LAZZARO'

# %%
ritorno = fit_arima.compute(stazione, 5, 1)
# Out:
# 12:13:35 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:15:10 - cmdstanpy - INFO - CmdStan done processing.
# 12:15:10 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/br1/PythonProjects/PythonStats/ARMA_bayesian_project/general_model_diff_1/code.stan', line 80, column 2 to column 25)
# Consider re-running with show_console=True if the above output is unclear!

# %%
az.summary(ritorno['inference_data'], var_names=['phi','theta','sigma','y_start'])
# Out:
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# phi[0]      0.694  0.056   0.588    0.801      0.001    0.001    4507.0
# phi[1]     -0.097  0.065  -0.222    0.021      0.001    0.001    4538.0
# phi[2]     -0.098  0.061  -0.210    0.021      0.001    0.001    4733.0
# phi[3]      0.066  0.066  -0.061    0.188      0.001    0.001    3243.0
# phi[4]     -0.027  0.055  -0.130    0.075      0.001    0.001    3171.0
# theta[0]   -0.949  0.022  -0.983   -0.906      0.000    0.000    3682.0
# sigma       0.152  0.006   0.142    0.163      0.000    0.000    8365.0
# y_start[0]  0.991  0.959  -0.768    2.835      0.010    0.010    8924.0
# y_start[1]  0.993  0.950  -0.712    2.835      0.011    0.010    8014.0
# y_start[2]  1.243  1.037  -0.625    3.175      0.015    0.011    4982.0
# y_start[3]  0.734  0.947  -1.006    2.477      0.015    0.011    3938.0
# y_start[4]  1.565  0.517   0.598    2.573      0.009    0.007    3048.0
# y_start[5]  1.641  0.320   1.015    2.222      0.006    0.004    3194.0
#
#             ess_tail  r_hat
# phi[0]        3174.0    1.0
# phi[1]        3443.0    1.0
# phi[2]        4208.0    1.0
# phi[3]        3196.0    1.0
# phi[4]        3929.0    1.0
# theta[0]      2148.0    1.0
# sigma         3927.0    1.0
# y_start[0]    3784.0    1.0
# y_start[1]    3926.0    1.0
# y_start[2]    4031.0    1.0
# y_start[3]    3791.0    1.0
# y_start[4]    2670.0    1.0
# y_start[5]    3095.0    1.0

# %%
az.plot_trace(ritorno['inference_data'], var_names=['phi','theta','sigma'])
# Out:
# array([[<AxesSubplot: title={'center': 'phi'}>,
#         <AxesSubplot: title={'center': 'phi'}>],
#        [<AxesSubplot: title={'center': 'theta'}>,
#         <AxesSubplot: title={'center': 'theta'}>],
#        [<AxesSubplot: title={'center': 'sigma'}>,
#         <AxesSubplot: title={'center': 'sigma'}>]], dtype=object)

# %%
az.plot_posterior(ritorno['inference_data'], var_names=['phi','theta','sigma'], hdi_prob=0.95)
# Out:
# array([[<AxesSubplot: title={'center': 'phi\n0'}>,
#         <AxesSubplot: title={'center': 'phi\n1'}>,
#         <AxesSubplot: title={'center': 'phi\n2'}>],
#        [<AxesSubplot: title={'center': 'phi\n3'}>,
#         <AxesSubplot: title={'center': 'phi\n4'}>,
#         <AxesSubplot: title={'center': 'theta\n0'}>],
#        [<AxesSubplot: title={'center': 'sigma'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
az.plot_posterior(ritorno['reconstructed_y'], hdi_prob=0.95)
# Out:
# array([[<AxesSubplot: title={'center': '2018-02-14'}>,
#         <AxesSubplot: title={'center': '2018-05-02'}>,
#         <AxesSubplot: title={'center': '2018-09-19'}>],
#        [<AxesSubplot: title={'center': '2018-10-17'}>,
#         <AxesSubplot: title={'center': '2018-10-18'}>,
#         <AxesSubplot: title={'center': '2018-12-31'}>]], dtype=object)

# %%
sns.lineplot(df[stazione])
# Out:
# <AxesSubplot: xlabel='Date', ylabel='S. LAZZARO'>
